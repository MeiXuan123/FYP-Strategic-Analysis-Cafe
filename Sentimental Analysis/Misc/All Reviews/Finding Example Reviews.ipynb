# %%
import pandas as pd
Resturants =  pd.read_excel(r"C:\Users\Mabel Lim\Google Drive\FYP\Sentimental Analysis\Sentimental_Burpple.xlsx")
AllNames = Resturants.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR = AllNames['Title'].tolist()

#for Negative reviews

NegativeReviews = pd.read_excel(r"C:\Users\Mabel Lim\Google Drive\FYP\Sentimental Analysis\Burpple_Negative_Reviews.xlsx")
NegNames = NegativeReviews.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoRNeg = NegNames['Title'].tolist()

NegReviews = []
maxNo = 0
polarity = NegativeReviews['polarity'].tolist()
Negcafename = NegativeReviews['Café_Names'].tolist()
names = AllNames['Café_Names'].tolist()
rev = NegativeReviews['Review'].tolist()
num = len(NoRNeg)
pos = 0
poss = 0

for i in names:
    if i in Negcafename:
        NegReviews.append("Yes")
    else:
        NegReviews.append("")
        
num1 = len(NegReviews)
NegReviews1 = []
counta = 0
pos1 = 0
poss1 = 0

for i in range(0, num1):
    if NegReviews[i] == "Yes":
        pos1 = pos1 + NoRNeg[counta]
        for x in range (poss1, pos1):
            if abs(polarity[x]) > maxNo:
                maxNo = abs(polarity[x])
        NegReviews1.append(rev[x])
        poss1 = pos1
        counta = counta +1
    else:
        NegReviews1.append("")
        
NegReviews2 = pd.Series(NegReviews1)
AllNames['Negative_Review'] = NegReviews2.values

#Neutral Reviews

NeutralReviews = pd.read_excel(r"C:\Users\Mabel Lim\Google Drive\FYP\Sentimental Analysis\Burpple_Neutral_Reviews.xlsx")
NeuNames = NeutralReviews.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoRNeu = NeuNames['Title'].tolist()

NeuReviews = []
minNo = 1
polarity = NeutralReviews['polarity'].tolist()
Neucafename = NeutralReviews['Café_Names'].tolist()
names = AllNames['Café_Names'].tolist()
rev = NeutralReviews['Review'].tolist()
num = len(NoRNeu)
pos = 0
poss = 0

for i in names:
    if i in Neucafename:
        NeuReviews.append("Yes")
    else:
        NeuReviews.append("")
        
num1 = len(NeuReviews)
NeuReviews1 = []
counta = 0
pos1 = 0
poss1 = 0

for i in range(0, num1):
    if NeuReviews[i] == "Yes":
        pos1 = pos1 + NoRNeu[counta]
        for x in range (poss1, pos1):
            if abs(polarity[x]) < minNo:
                minNo = abs(polarity[x])
        NeuReviews1.append(rev[x])
        poss1 = pos1
        counta = counta +1
    else:
        NeuReviews1.append("")
        
NeuReviews2 = pd.Series(NeuReviews1)
AllNames['Neutral_Review'] = NeuReviews2.values

#Positive Reviews

PositiveReviews = pd.read_excel(r"C:\Users\Mabel Lim\Google Drive\FYP\Sentimental Analysis\Burpple_Positive_Reviews.xlsx")
PovNames = PositiveReviews.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoRPov = PovNames['Title'].tolist()

PovReviews = []
maxNo = 1
polarity = PositiveReviews['polarity'].tolist()
Povcafename = PositiveReviews['Café_Names'].tolist()
names = AllNames['Café_Names'].tolist()
rev = PositiveReviews['Review'].tolist()
num = len(NoRPov)
pos = 0
poss = 0

for i in names:
    if i in Povcafename:
        PovReviews.append("Yes")
    else:
        PovReviews.append("")
        
num1 = len(PovReviews)
PovReviews1 = []
counta = 0
pos1 = 0
poss1 = 0

for i in range(0, num1):
    if PovReviews[i] == "Yes":
        pos1 = pos1 + NoRPov[counta]
        for x in range (poss1, pos1):
            if abs(polarity[x]) > maxNo:
                maxNo = abs(polarity[x])
        PovReviews1.append(rev[x])
        poss1 = pos1
        counta = counta +1
    else:
        PovReviews1.append("")
        
PovReviews2 = pd.Series(PovReviews1)
AllNames['Positive_Review'] = PovReviews2.values

#Positive Reviews

PositiveReviews = pd.read_excel(r"C:\Users\Mabel Lim\Google Drive\FYP\Sentimental Analysis\Burpple_Positive_Reviews.xlsx")
PovNames = PositiveReviews.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoRPov = PovNames['Title'].tolist()

PovReviews = []
maxNo = 1
polarity = PositiveReviews['polarity'].tolist()
Povcafename = PositiveReviews['Café_Names'].tolist()
names = AllNames['Café_Names'].tolist()
rev = PositiveReviews['Review'].tolist()
num = len(NoRPov)
pos = 0
poss = 0

for i in names:
    if i in Povcafename:
        PovReviews.append("Yes")
    else:
        PovReviews.append("")
        
num1 = len(PovReviews)
PovReviews1 = []
counta = 0
pos1 = 0
poss1 = 0

for i in range(0, num1):
    if PovReviews[i] == "Yes":
        pos1 = pos1 + NoRPov[counta]
        for x in range (poss1, pos1):
            if abs(polarity[x]) > maxNo:
                maxNo = abs(polarity[x])
        PovReviews1.append(rev[x])
        poss1 = pos1
        counta = counta +1
    else:
        PovReviews1.append("")
        
PovReviews2 = pd.Series(PovReviews1)
AllNames['Positive_Review'] = PovReviews2.values

AllNames.columns = ['Café_Names', 'Count', 'Negative_Review', 'Neutral_Review','Positive_Review']

ex = pd.ExcelWriter('Example_Reviews.xlsx', options={'encoding':'utf-8'})
AllNames.to_excel(ex, 'Data', index=False)

# %%
AllNames
# Out:
#                                            Café_Names  Count  \
# 0                       The Populus Coffee & Food Co.    362
# 1                                         Xiao Ya Tou    187
# 2                                       Bearded Bella     48
# 3                                           The Lokal    479
# 4                               Chong Wen Ge Cafe 崇文阁     70
# 5                                     Common Man Stan     26
# 6                                Lunar Coffee Brewers     66
# 7                                           Guac & Go     24
# 8                                                 1KS     20
# 9                       Well Dressed Salad Bar & Cafe     38
# 10                             Group Therapy (Duxton)    292
# 11                                 VENUE by Sebastian     79
# 12                                         NINJA BOWL    348
# 13                                    My Awesome Cafe     85
# 14                                Café & Bar Gavroche     47
# 15                                    JAPAN RAIL CAFE     70
# 16                                      Dapper Coffee    147
# 17                              Nylon Coffee Roasters    111
# 18                                        The Moments     96
# 19                                   Eight Cafe & Bar     33
# 20                                             Truffs     26
# 21                                            Pantler    120
# 22                                               Luxe     90
# 23                                 Monument Lifestyle     20
# 24                           PS.Cafe (Ann Siang Hill)    104
# 25                The Sandwich Shop (Robinson Centre)      4
# 26                         Orchid Cafe (Orchid Hotel)     14
# 27                                   Just Want Coffee     37
# 28                                Café 2000 (M Hotel)     37
# 29  Good Morning Nanyang Cafe 早安南洋 (Maxwell Chambers)     13
# ..                                                ...    ...
# 51                               HashTag88 Cafe & Bar      5
# 52                                  Tom N Toms Coffee     43
# 53                        Joe & Dough (Capital Tower)     26
# 54                       Secret Recipe (CPF Building)      6
# 55             6oz Espresso Bar (Tokio Marine Centre)     28
# 56                      Dimbulah Coffee (Anson House)      8
# 57                          Kopi Alley (Icon Village)      2
# 58                 Cedele Bakery Cafe (Robinson Road)      3
# 59   The Coffee Bean & Tea Leaf (International Plaza)      4
# 60                Costa Coffee (Sofitel So Singapore)      8
# 61                          Kanoom - Little Thai Cafe      6
# 62             Joe & The Juice (Tanjong Pagar Centre)      3
# 63                     Rocky Master (Mapletree Anson)      2
# 64                                      BLUEMIST Cafe      8
# 65                     Nanyang Old Coffee (Chinatown)      4
# 66                                            Kosnica     28
# 67                                     Urban Fairways     11
# 68                      Yellow Cup Coffee (AXA Tower)      3
# 69          Trung Nguyen Coffee (International Plaza)      8
# 70                                         Ash & Char     41
# 71                            Rookery (Capital Tower)      5
# 72             Coffee & Toast (Tanjong Pagar Xchange)      3
# 73                    Patisserie G (Downtown Gallery)      5
# 74                                          Dudu Cafe      4
# 75                   The Providore (Downtown Gallery)     21
# 76                         The New Harbour Café & Bar     25
# 77                       Passion Cafe (Tanjong Pagar)      4
# 78                                       Socks & Pans      9
# 79                                             Loloku     19
# 80                          Starbucks (Capital Tower)     12
#
#                                       Negative_Review  \
# 0        I'm so gonna whack hard on their food menu!!
# 1   Try this from the lunch menu at Little Husband...
# 2   slow cooked pork jowls, poached eggs, green ho...
# 3   This was hard and tasted burnt 😐 no amount of ...
# 4   You didn't hear me wrong! It's inside a temple...
# 5
# 6   It was sprinkled with homemade shortbread crum...
# 7
# 8
# 9
# 10  My lunch time adventure alone: Chicken Mushroo...
# 11  🌻\n•\n🥘: Angel hair pasta, sakura ebi, konbu, ...
# 12  Getting all those shit done literally as it says.
# 13  It helps that MAC is walking distance from RHC...
# 14  Smashed eggplant caviar smeared on toasted Sou...
# 15  Comes with plenty of greens so you don't need ...
# 16  So much left undone. But it's a new week… get ...
# 17
# 18  In the sun he shone\nA ubiquitous quo\nIf I fo...
# 19  The juicy and succulent foie gras and poached ...
# 20  Delicate, thick and dense. One mouthful and yo...
# 21  My favourite Pesto Chicken sandwich from @pant...
# 22
# 23                      slow weekday afternoons are ♡
# 24  Truffle fries so hard we had an aching jaw and...
# 25
# 26
# 27
# 28  All this food for a mere SGD$59++ Read about t...
# 29
# ..                                                ...
# 51
# 52  Other than the usual suspects, do let me know ...
# 53
# 54  This dish is da BOMB! Every single time at eve...
# 55
# 56
# 57
# 58
# 59
# 60
# 61
# 62
# 63
# 64
# 65
# 66  •\nAnyway, the matcha waffle @kosnica.singapor...
# 67
# 68
# 69
# 70  But if you really want the truth, make a beeli...
# 71
# 72
# 73
# 74                            I can eat this everyday
# 75
# 76  A choice of a cheesy sausage and chicken sausa...
# 77  The curry is very thick. I like it, but it's n...
# 78
# 79
# 80  1 Mar’18, Thu☁️\nNeed tt boost and for there’s...
#
#                                        Neutral_Review  \
# 0                                     #顾名不思义 #Burpple
# 1   This is the 36h oven roasted pork belly with f...
# 2       Gotta try the white chocolate with raspberry.
# 3   😋👍🏻 #singapore #igsg #sgig #lifestyle  #instag...
# 4   yeap this is what I found thanks to the sugges...
# 5                                            #burpple
# 6   The silence beckons the shy, subtle details ou...
# 7       http://danielfooddiary.com/2015/01/14/guacngo
# 8   How are you spending your Christmas Eve? #sgfo...
# 9   Creative or what? More importantly, it taste v...
# 10  #sgcafe #sg_ig #sgigfoodie #sgig #sgfood #food...
# 11  They were crispy, buttery and garlicky. I will...
# 12  From Mavrx Coffee, a new cafe located at 1A Du...
# 13  salmon quiche and greens #food #foodies #sgfoo...
# 14                     Artsy fartsy. #americano #cafe
# 15  With the set lunch, I dont know why I chose th...
# 16  Love the flatwhite #coffee too and definitely ...
# 17  You're my honeybunch, sugarplum \nPumpy-umpy-u...
# 18  Newly open cafe in CBD area in Tanjong Pajar. ...
# 19  Look no further #eightcafebar is where u need ...
# 20                                        ) @nitsuj_o
# 21                                🍰🍰🍰 #dessertmonster
# 22  Note: NO ricotta hotcake is complete without i...
# 23  And nestled within this cozy spot is a cafe wh...
# 24  dempsey igsg hubfood 30likes 20likes water gla...
# 25                                     Tummmmny yummy
# 26  Roast Chicken Noodle for late dinner! Ooh ha? ...
# 27  new cafe hunt ~ @cozycorner #cafe #tiramisu #g...
# 28                      Omelette with everything in 😁
# 29                  #foodporn #goodmorningnanyangcafe
# ..                                                ...
# 51                  😂\n#onmytable #handsinframe #igsg
# 52  #tomntoms #greentea #style #fashion #magazine ...
# 53                          #jdxmasparty15 #joendough
# 54
# 55        Salsa Bacon & Egg with Americano #breakfast
# 56                                            #coffee
# 57
# 58
# 59  One of my faves and definitely something I can...
# 60  Farewell tea break with industry friend.\nSo s...
# 61  In order to serve them to you, the chef had pu...
# 62  Juicing strawberries, apples and ginger to get...
# 63  Have you ever seen cucumber, quail egg and cut...
# 64           $11 bucks for a pint of beer. Nuff said!
# 65  A Chinese style Churrasco in my opinion, they ...
# 66  The gelato is quite impressive as it tasted li...
# 67  Waffles does not go out of style, it seems. On...
# 68  •\n#burpple #burpplesg @burpple #hungrygowhere...
# 69
# 70  Check out @ashandcharsg for a cuppa. Serving D...
# 71  Some truffle Mushroom soup to get the day star...
# 72  Drinking kopi ☕️while waiting for tonight's event
# 73  The roasty octopus squelched in crunchy surren...
# 74  Mee Rebus + Fish Ngoh Hiang. This is a Chinese...
# 75         Kato from The Providore, Downtown Gallery.
# 76                                     Monster Burger
# 77  who else prefers bee hoon over bread for break...
# 78  Available all day, this flavourful sandwich is...
# 79  Had your coffee break yet? ☕\n#MsJaniceEats_Co...
# 80                                      Rainy mornin'
#
#                                       Positive_Review
# 0                2 more days to go and I'm out of it.
# 1   Thank you my handmodels and the wonderful comp...
# 2   Supposedly mocha but didn't really get the cof...
# 3   The way his eyes lit up when they brought this...
# 4   Totally  peranakan ...food and decor. So this ...
# 5          One of the best chai latte I had recently.
# 6                         So refreshing on a hot day.
# 7            Huge dollop of guacamole. Worth the $14!
# 8   Simple, handcrafted cappuccino. Bright red cup...
# 9   Thanks for making for wholesome snacks 😋😋😋 Flu...
# 10  Blueberry Pancakes with lots of Strawberries, ...
# 11  We ordered a few small plates and mains to sha...
# 12  So clean, simple & quintessential!  No complic...
# 13  I'm not sure if I've eaten anything greener an...
# 14                         Best tartines in Singapore
# 15  This was one of the healthier option (besides ...
# 16  Thanks pang for the lovely #dappercoffee #coff...
# 17        Finally trying the coffee at this place! :)
# 18  This photography-cafe place is really quite un...
# 19  The mussels, prawns and scallop were fresh. Sa...
# 20                  Lovely place for chocolate lovers
# 21  We hear it's a must-try with its delicious mix...
# 22  @LuxeSydney opened its Singapore outfit @LuxeL...
# 23  A thick slice of sourdough toast stuffed with ...
# 24  Even shioker when paired with great company an...
# 25                          Good old Aussie flavours!
# 26  People staying or working at Tanjong Pagar. Do...
# 27  Nice handmade tiramisu! Only cost $5.50, quite...
# 28  Never too full for desserts 🍰🍮🍦thank you @mhot...
# 29  And therefore the best. ieatishootipost has al...
# ..                                                ...
# 51  Not much diff as the most important is the cru...
# 52     Who said toast and coffee won't make you full?
# 53  The bread is deliciously good.. #sgig #igsg #s...
# 54  This dish is drowning in mozzarella cheese hea...
# 55  Something wonderful to compliment my marvellio...
# 56
# 57  Jam & toast #insplaceus #insplaceusapp #photoo...
# 58  The crunch from the almond strips contrasts wi...
# 59  Having the look good but no nice mud pie at co...
# 60  Second time I have tried this outlet.\nSomehow...
# 61  If you are in for a light tea break, Kanoom al...
# 62  Hangover Heaven ($6.90)\nNo hangover here but ...
# 63   Rocky Masters served the best ice blended coffee
# 64  One plate of cheesy goodness!! #comfortfood Ha...
# 65  Rediscover the good taste of olden Singapore t...
# 66  From this new ice-cream parlour that opened th...
# 67  It comes paired with the MSW Durian that was c...
# 68  Thank you Hans for the warm hospitality at Yel...
# 69  tried Trung Nyugen's #vietnamese drip #coffee ...
# 70  Garnished with sliced fuji apples. So loving t...
# 71  got it as part of the set lunch which comes wi...
# 72  Feel like some time ago since I last drink Teh...
# 73  Lemon 🍋 Tart\nOne of the free food and drink c...
# 74
# 75  Congratulations to Robert and the rest of the ...
# 76  #dinner with mummy \nBrought her back to one o...
# 77                TGIF Brekkie! 🍝 Good Morning World!
# 78  Surprisingly good local Kopi served at this sp...
# 79  Really solid bowl of poke. The Wikiwiki bowl c...
# 80         Have even thinking about it the whole day.
#
# [81 rows x 5 columns]
