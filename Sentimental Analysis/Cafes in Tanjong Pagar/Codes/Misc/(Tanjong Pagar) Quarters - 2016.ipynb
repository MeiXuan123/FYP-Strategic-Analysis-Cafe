# %%
import pandas as pd
import datetime
import math
import numpy

Burpple = pd.read_excel(r"(TP) From2016_Sentimental_Burpple.xlsx")
Dates = Dates = Burpple['Date'].tolist()

condition = ''
Form = []
why = []
day = ''
mon = ''
year = ''
monyear = ''
Date = ''

for i in Dates:
    
    condition = i.split()[2]
    
    if condition == "ago":
        day = i.split()[0]
        monyear = "May 2018"
        year = "2018"
        Date = day + " " + monyear
        Form.append(Date)
        why.append(year)
        
    elif condition == "at":
        mon = i.split()[0]
        day = i.split()[1]
        year = "2018"
        Date = day+" "+ mon + " 2018"
        Form.append(Date)
        why.append(year)
        
    else:
        day = i.split()[1]
        day = day.replace(',','')
        mon = i.split()[0]
        year = i.split()[2]
        Date = day + " " + mon + " " + year
        Form.append(Date)
        why.append(year)
        
 
              
num = len(Burpple)
NewDate = []
Quart = []
Q = 0
yy = ''
strdate = ''

for i in range (0, num):
    Date = datetime.datetime.strptime(Form[i], '%d %b %Y').strftime('%d/%m/%Y')
    Date = datetime.datetime.strptime(Date,'%d/%m/%Y')
    
    NewDate.append(Date)

    Q=math.ceil(Date.month/3.)
    #print(Q)
    Quart.append(Q)
    
    #strdate = str(Date)
    #yy = Date.Year
    #bpyear.append(yy)
    
       
FormatDate = pd.Series(NewDate)
Burpple['Formated_Date'] = FormatDate.values

Quarter = pd.Series(Quart)
Burpple['Quarter'] = Quarter.values

Year = pd.Series(why)
Burpple['Year'] = Year.values

ex = pd.ExcelWriter('(TP) Quarters.xlsx', options={'encoding':'utf-8'})
Burpple.to_excel(ex, 'Data', index=False)

#AllNames = Burpple.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
#NoR = AllNames['Title'].tolist()


### sorting the data by Years

y2016 = pd.DataFrame()
y2017 = pd.DataFrame()
y2018 = pd.DataFrame()
No2016 = []
No2017 = []
No2018 = []

for i in range (0, num):
    if why[i] == '2016':
        No2016.append(i)
    if why[i] == '2017':
        No2017.append(i)
    if why[i] == '2018':
        No2018.append(i)
    
y2016 = pd.DataFrame(Burpple.iloc[No2016])
y2017 = pd.DataFrame(Burpple.iloc[No2017])
y2018 = pd.DataFrame(Burpple.iloc[No2018])


y2016 = y2016.reset_index(drop = True)
y2017 = y2017.reset_index(drop = True)
y2018 = y2018.reset_index(drop = True)

#next decide how you want to split the data.
#seperate each year into diff files? How about the average sentiment?

###  Resturant  Avg_sentiment Quarter_1 Quarter_2 Quarter_3 Quarter_4
###  xxx        0.01          0.2       0.021     0.45      0.46

# %%
### for the year 2016

AllNames2016 = y2016.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR2016 = AllNames2016['Title'].tolist()

Quarter = y2016['Quarter'].tolist()

num = len(y2016)
No1 = []
No2 =[]
No3 =[]
No4 =[]

for i in range(0, num):
    if Quarter[i] == 1:
        No1.append(i)
    if Quarter[i] == 2:
        No2.append(i)
    if Quarter[i] == 3:
        No3.append(i)
    if Quarter[i] == 4:
        No4.append(i)
        
#creating databases based on the quarter

q1 = pd.DataFrame(y2016.iloc[No1])
q2 = pd.DataFrame(y2016.iloc[No2])
q3 = pd.DataFrame(y2016.iloc[No3])
q4 = pd.DataFrame(y2016.iloc[No4])

# Quarter 1

AllNames1 = q1.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR1 = AllNames1['Title'].tolist()

Q1YN =[]
names = AllNames2016['Café_Names'].tolist()
names1 = AllNames1['Café_Names'].tolist()

for i in names:
    if i in names1:
        Q1YN.append("Yes")
    else:
        Q1YN.append("")

polarity = q1['polarity'].tolist()        
num = len(NoR2016)
pos = 0
poss = 0
counta = 0
total = float(0)
average = float(0)
avg1 = []

for i in range (0, num):
    if Q1YN[i] == "Yes":
        pos = pos + NoR1[counta]
        total = 0
        average = 0
        for x in range(poss, pos):
            total = total + polarity[x]
        average = total / NoR1[counta]
        avg1.append(average)
        poss = pos
        counta = counta + 1
    else:
        avg1.append(0)
        
Avg_Q1 = pd.Series(avg1)       
AllNames2016['Q1_Average_Polarity'] = Avg_Q1.values

# %%
# Quarter 2

AllNames2 = q2.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR2 = AllNames2['Title'].tolist()

Q2YN =[]
names = AllNames2016['Café_Names'].tolist()
names2 = AllNames2['Café_Names'].tolist()

for i in names:
    if i in names2:
        Q2YN.append("Yes")
    else:
        Q2YN.append("")

polarity = q2['polarity'].tolist()        
num = len(NoR2016)
pos = 0
poss = 0
counta = 0
total = float(0)
average = float(0)
avg2 = []

for i in range (0, num):
    if Q2YN[i] == "Yes":
        pos = pos + NoR2[counta]
        total = 0
        average = 0
        for x in range(poss, pos):
            total = total + polarity[x]
        average = total / NoR2[counta]
        avg2.append(average)
        poss = pos
        counta = counta + 1
    else:
        avg2.append(0)
        
Avg_Q2 = pd.Series(avg2)       
AllNames2016['Q2_Average_Polarity'] = Avg_Q2.values
# Out:
#                                            Café_Names  Title  \
# 0                       The Populus Coffee & Food Co.    195
# 1                                         Xiao Ya Tou     45
# 2                                           The Lokal    121
# 3                               Chong Wen Ge Cafe 崇文阁     51
# 4                                           Guac & Go      5
# 5                       Well Dressed Salad Bar & Cafe      8
# 6                              Group Therapy (Duxton)     18
# 7                                          NINJA BOWL    199
# 8                             Mavrx Coffee Apothecary      6
# 9                                     My Awesome Cafe      9
# 10                                Café & Bar Gavroche      1
# 11                                    JAPAN RAIL CAFE      9
# 12                                      Dapper Coffee     76
# 13                              Nylon Coffee Roasters     13
# 14                                      5 The Moments     13
# 15                                   Eight Cafe & Bar      1
# 16                                            Pantler     21
# 17                                               Luxe     20
# 18                           PS.Cafe (Ann Siang Hill)     11
# 19                The Sandwich Shop (Robinson Centre)      1
# 20                         Orchid Cafe (Orchid Hotel)      1
# 21                                   Just Want Coffee      1
# 22                                Café 2000 (M Hotel)      7
# 23  Good Morning Nanyang Cafe 早安南洋 (Maxwell Chambers)      9
# 24                         Drury Lane (Tanjong Pagar)     23
# 25                          Royz et Vous (Telok Ayer)     28
# 26             Coffee Break (Amoy Street Food Centre)      6
# 27                                   The White Rocket      3
# 28                Jewel Coffee (Tanjong Pagar Centre)      3
# 29                                         Fat Prince      7
# 30                         Bingki Korean Dessert Cafe     39
# 31                                           Epiphyte     35
# 32                    Alchemist (International Plaza)     11
# 33                    Mellower Coffee (Tanjong Pagar)     11
# 34        Merchants Wine Cellar & Store (Duxton Hill)     10
# 35  Ah Seng (Hai Nam) Coffee (Amoy Street Food Cen...      6
# 36                               HashTag88 Cafe & Bar      3
# 37                                  Tom N Toms Coffee      7
# 38                        Joe & Dough (Capital Tower)     13
# 39             6oz Espresso Bar (Tokio Marine Centre)      4
# 40   The Coffee Bean & Tea Leaf (International Plaza)      2
# 41                Costa Coffee (Sofitel So Singapore)      1
# 42                          Kanoom - Little Thai Cafe      2
# 43                                      BLUEMIST Cafe      2
# 44                     Nanyang Old Coffee (Chinatown)      1
# 45                                            Kosnica      8
# 46                                     Urban Fairways     10
# 47                      Yellow Cup Coffee (AXA Tower)      1
# 48          Trung Nguyen Coffee (International Plaza)      3
# 49                                         Ash & Char     22
# 50             Coffee & Toast (Tanjong Pagar Xchange)      1
# 51                         The New Harbour Café & Bar      2
# 52                       Passion Cafe (Tanjong Pagar)      1
# 53                                       Socks & Pans      5
# 54                          Starbucks (Capital Tower)      1
#
#     Q1_Average_Polarity  Q2_Average_Polarity
# 0              0.226939             0.177353
# 1              0.000000             0.184949
# 2              0.192901             0.259222
# 3              0.000000             0.140540
# 4              0.350000             0.100000
# 5              0.530000             0.417500
# 6              0.199405             0.223576
# 7              0.000000             0.205940
# 8              0.276389             0.020594
# 9              0.000000             0.005820
# 10             0.000000             0.000000
# 11             0.000000             0.000000
# 12             0.204902             0.109823
# 13             0.087500             0.049940
# 14             0.142857             0.225556
# 15             0.125000             0.000000
# 16             0.177280             0.094219
# 17             0.120939             0.189448
# 18             0.441667             0.097917
# 19             0.000000             0.000000
# 20             0.000000             0.000000
# 21             0.000000             0.600000
# 22             0.000000             0.290109
# 23             0.037500             0.000000
# 24             0.344365             0.171989
# 25             0.362745             0.356808
# 26             0.137037             0.118403
# 27             0.071111             0.000000
# 28             0.000000             0.000000
# 29             0.000000             0.000000
# 30             0.119700             0.171119
# 31             0.000000             0.000000
# 32             0.000000             0.064815
# 33             0.000000             0.057482
# 34             0.225000             0.000000
# 35             0.000000             0.366667
# 36             0.000000             0.155934
# 37             0.185000             0.000000
# 38             0.187143             0.277083
# 39             0.000000            -0.300000
# 40             0.000000            -0.100000
# 41             0.000000             0.000000
# 42            -0.141667             0.337963
# 43             0.000000             0.275000
# 44             0.000000             0.000000
# 45             0.000000             0.000000
# 46             0.218367             0.000000
# 47             0.000000             0.000000
# 48             0.249727             0.000000
# 49             0.000000             0.000000
# 50             0.000000             0.000000
# 51             0.125000             0.000000
# 52             0.000000             0.000000
# 53            -0.003333             0.211275
# 54             0.000000             0.000000

# %%
# Quarter 3

AllNames3 = q3.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR3 = AllNames3['Title'].tolist()

Q3YN =[]
names = AllNames2016['Café_Names'].tolist()
names3 = AllNames3['Café_Names'].tolist()

for i in names:
    if i in names3:
        Q3YN.append("Yes")
    else:
        Q3YN.append("")

polarity = q3['polarity'].tolist()        
num = len(NoR2016)
pos = 0
poss = 0
counta = 0
total = float(0)
average = float(0)
avg3 = []

for i in range (0, num):
    if Q3YN[i] == "Yes":
        pos = pos + NoR3[counta]
        total = 0
        average = 0
        for x in range(poss, pos):
            total = total + polarity[x]
        average = total / NoR3[counta]
        avg3.append(average)
        poss = pos
        counta = counta + 1
    else:
        avg3.append(0)
        
Avg_Q3 = pd.Series(avg3)       
AllNames2016['Q3_Average_Polarity'] = Avg_Q3.values

# %%
# Quarter 4

AllNames4 = q4.groupby('Café_Names', sort=False, as_index=False).Title.count().reset_index(drop=True)
NoR4 = AllNames4['Title'].tolist()

Q4YN =[]
names = AllNames2016['Café_Names'].tolist()
names4 = AllNames4['Café_Names'].tolist()

for i in names:
    if i in names4:
        Q4YN.append("Yes")
    else:
        Q4YN.append("")

polarity = q4['polarity'].tolist()        
num = len(NoR2016)
pos = 0
poss = 0
counta = 0
total = float(0)
average = float(0)
avg4 = []

for i in range (0, num):
    if Q4YN[i] == "Yes":
        pos = pos + NoR4[counta]
        total = 0
        average = 0
        for x in range(poss, pos):
            total = total + polarity[x]
        average = total / NoR4[counta]
        avg4.append(average)
        poss = pos
        counta = counta + 1
    else:
        avg4.append(0)
        
Avg_Q4 = pd.Series(avg4)       
AllNames2016['Q4_Average_Polarity'] = Avg_Q4.values

# %%
AllNames2016.columns = ['Café_Names', 'Count','Q1_Average_Polarity', 'Q2_Average_Polarity','Q3_Average_Polarity', 'Q4_Average_Polarity']

ex = pd.ExcelWriter('(TP) 2016_Average Sentiment by Quarter.xlsx', options={'encoding':'utf-8'})
AllNames2016.to_excel(ex, 'Data', index=False)

# %%
AllNames2016
# Out:
#                                            Café_Names  Count  \
# 0                       The Populus Coffee & Food Co.    195
# 1                                         Xiao Ya Tou     45
# 2                                           The Lokal    121
# 3                               Chong Wen Ge Cafe 崇文阁     51
# 4                                           Guac & Go      5
# 5                       Well Dressed Salad Bar & Cafe      8
# 6                              Group Therapy (Duxton)     18
# 7                                          NINJA BOWL    199
# 8                             Mavrx Coffee Apothecary      6
# 9                                     My Awesome Cafe      9
# 10                                Café & Bar Gavroche      1
# 11                                    JAPAN RAIL CAFE      9
# 12                                      Dapper Coffee     76
# 13                              Nylon Coffee Roasters     13
# 14                                      5 The Moments     13
# 15                                   Eight Cafe & Bar      1
# 16                                            Pantler     21
# 17                                               Luxe     20
# 18                           PS.Cafe (Ann Siang Hill)     11
# 19                The Sandwich Shop (Robinson Centre)      1
# 20                         Orchid Cafe (Orchid Hotel)      1
# 21                                   Just Want Coffee      1
# 22                                Café 2000 (M Hotel)      7
# 23  Good Morning Nanyang Cafe 早安南洋 (Maxwell Chambers)      9
# 24                         Drury Lane (Tanjong Pagar)     23
# 25                          Royz et Vous (Telok Ayer)     28
# 26             Coffee Break (Amoy Street Food Centre)      6
# 27                                   The White Rocket      3
# 28                Jewel Coffee (Tanjong Pagar Centre)      3
# 29                                         Fat Prince      7
# 30                         Bingki Korean Dessert Cafe     39
# 31                                           Epiphyte     35
# 32                    Alchemist (International Plaza)     11
# 33                    Mellower Coffee (Tanjong Pagar)     11
# 34        Merchants Wine Cellar & Store (Duxton Hill)     10
# 35  Ah Seng (Hai Nam) Coffee (Amoy Street Food Cen...      6
# 36                               HashTag88 Cafe & Bar      3
# 37                                  Tom N Toms Coffee      7
# 38                        Joe & Dough (Capital Tower)     13
# 39             6oz Espresso Bar (Tokio Marine Centre)      4
# 40   The Coffee Bean & Tea Leaf (International Plaza)      2
# 41                Costa Coffee (Sofitel So Singapore)      1
# 42                          Kanoom - Little Thai Cafe      2
# 43                                      BLUEMIST Cafe      2
# 44                     Nanyang Old Coffee (Chinatown)      1
# 45                                            Kosnica      8
# 46                                     Urban Fairways     10
# 47                      Yellow Cup Coffee (AXA Tower)      1
# 48          Trung Nguyen Coffee (International Plaza)      3
# 49                                         Ash & Char     22
# 50             Coffee & Toast (Tanjong Pagar Xchange)      1
# 51                         The New Harbour Café & Bar      2
# 52                       Passion Cafe (Tanjong Pagar)      1
# 53                                       Socks & Pans      5
# 54                          Starbucks (Capital Tower)      1
#
#     Q1_Average_Polarity  Q2_Average_Polarity  Q3_Average_Polarity  \
# 0              0.226939             0.177353             0.179688
# 1              0.000000             0.184949             0.286013
# 2              0.192901             0.259222             0.188448
# 3              0.000000             0.140540             0.167701
# 4              0.350000             0.100000             0.000000
# 5              0.530000             0.417500             0.083872
# 6              0.199405             0.223576             0.333333
# 7              0.000000             0.205940             0.178892
# 8              0.276389             0.020594             0.000000
# 9              0.000000             0.005820             0.326984
# 10             0.000000             0.000000             0.450000
# 11             0.000000             0.000000             0.000000
# 12             0.204902             0.109823             0.176210
# 13             0.087500             0.049940             0.142857
# 14             0.142857             0.225556             0.454745
# 15             0.125000             0.000000             0.000000
# 16             0.177280             0.094219             0.147857
# 17             0.120939             0.189448             0.111458
# 18             0.441667             0.097917             0.222321
# 19             0.000000             0.000000             0.400000
# 20             0.000000             0.000000             0.000000
# 21             0.000000             0.600000             0.000000
# 22             0.000000             0.290109            -0.167593
# 23             0.037500             0.000000             0.261312
# 24             0.344365             0.171989             0.163988
# 25             0.362745             0.356808             0.147328
# 26             0.137037             0.118403             0.082937
# 27             0.071111             0.000000             0.220833
# 28             0.000000             0.000000             0.000000
# 29             0.000000             0.000000             0.306061
# 30             0.119700             0.171119             0.317500
# 31             0.000000             0.000000             0.000000
# 32             0.000000             0.064815             0.129835
# 33             0.000000             0.057482             0.250000
# 34             0.225000             0.000000             0.023958
# 35             0.000000             0.366667             0.095760
# 36             0.000000             0.155934             0.000000
# 37             0.185000             0.000000             0.175000
# 38             0.187143             0.277083             0.000000
# 39             0.000000            -0.300000             0.000000
# 40             0.000000            -0.100000             0.000000
# 41             0.000000             0.000000             0.000000
# 42            -0.141667             0.337963             0.000000
# 43             0.000000             0.275000             0.000000
# 44             0.000000             0.000000            -0.010000
# 45             0.000000             0.000000             0.000000
# 46             0.218367             0.000000             0.000000
# 47             0.000000             0.000000             0.000000
# 48             0.249727             0.000000             0.000000
# 49             0.000000             0.000000             0.000000
# 50             0.000000             0.000000             0.000000
# 51             0.125000             0.000000             0.000000
# 52             0.000000             0.000000             0.000000
# 53            -0.003333             0.211275             0.324938
# 54             0.000000             0.000000             0.000000
#
#     Q4_Average_Polarity
# 0              0.193002
# 1              0.089109
# 2              0.246901
# 3              0.125738
# 4              0.135251
# 5              0.272415
# 6              0.290986
# 7              0.190391
# 8              0.000000
# 9              0.500000
# 10             0.000000
# 11             0.163460
# 12             0.294727
# 13             0.041667
# 14            -0.097112
# 15             0.000000
# 16             0.069792
# 17             0.072222
# 18             0.083333
# 19             0.000000
# 20             0.000000
# 21             0.000000
# 22             0.019583
# 23             0.251209
# 24             0.462500
# 25             0.347640
# 26             0.030556
# 27             0.000000
# 28             0.045238
# 29             0.105129
# 30             0.187824
# 31             0.131032
# 32             0.130294
# 33             0.097820
# 34             0.364167
# 35             0.000000
# 36             0.558333
# 37             0.140104
# 38             0.000000
# 39             0.206169
# 40             0.000000
# 41             0.000000
# 42             0.000000
# 43             0.000000
# 44             0.000000
# 45             0.183180
# 46             0.287273
# 47             0.000000
# 48             0.000000
# 49             0.144642
# 50             0.000000
# 51            -0.125000
# 52             0.000000
# 53             0.000000
# 54             0.000000

# %%
y2016[y2016['Café_Names'].str.contains("Costa Coffee")]
# Out:
#                                Café_Names          Date  \
# 1052  Costa Coffee (Sofitel So Singapore)  Nov 27, 2016
#
#                                                   Title    Review  \
# 1052  Enjoying a Flat White and toasted Turkey Ham &...  #burpple
#
#      Cleaned_Reviews  polarity  subjectivity Formated_Date  Quarter  Year
# 1052             NaN       0.0           0.0    2016-11-27        4  2016

# %%
AllNames1
# Out:
#                                            Café_Names  Title  \
# 0                       The Populus Coffee & Food Co.     70
# 1                                           The Lokal     40
# 2                                           Guac & Go      1
# 3                       Well Dressed Salad Bar & Cafe      1
# 4                              Group Therapy (Duxton)      3
# 5                             Mavrx Coffee Apothecary      3
# 6                                     My Awesome Cafe      2
# 7                                       Dapper Coffee      9
# 8                               Nylon Coffee Roasters      4
# 9                                       5 The Moments      1
# 10                                   Eight Cafe & Bar      1
# 11                                            Pantler      9
# 12                                               Luxe      6
# 13                           PS.Cafe (Ann Siang Hill)      2
# 14                         Orchid Cafe (Orchid Hotel)      1
# 15  Good Morning Nanyang Cafe 早安南洋 (Maxwell Chambers)      1
# 16                         Drury Lane (Tanjong Pagar)      6
# 17                          Royz et Vous (Telok Ayer)      2
# 18             Coffee Break (Amoy Street Food Centre)      1
# 19                                   The White Rocket      2
# 20                         Bingki Korean Dessert Cafe      5
# 21        Merchants Wine Cellar & Store (Duxton Hill)      1
# 22                                  Tom N Toms Coffee      2
# 23                        Joe & Dough (Capital Tower)      7
# 24             6oz Espresso Bar (Tokio Marine Centre)      1
# 25                          Kanoom - Little Thai Cafe      1
# 26                                     Urban Fairways      7
# 27          Trung Nguyen Coffee (International Plaza)      3
# 28             Coffee & Toast (Tanjong Pagar Xchange)      1
# 29                         The New Harbour Café & Bar      1
# 30                                       Socks & Pans      2
# 31                          Starbucks (Capital Tower)      1
#
#     Q1_Average_Polarity
# 0              0.226939
# 1              0.000000
# 2              0.000000
# 3              0.192901
# 4              0.000000
# 5              0.000000
# 6              0.000000
# 7              0.350000
# 8              0.000000
# 9              0.530000
# 10             0.199405
# 11             0.000000
# 12             0.000000
# 13             0.276389
# 14             0.000000
# 15             0.000000
# 16             0.000000
# 17             0.204902
# 18             0.087500
# 19             0.142857
# 20             0.125000
# 21             0.177280
# 22             0.120939
# 23             0.000000
# 24             0.441667
# 25             0.000000
# 26             0.000000
# 27             0.000000
# 28             0.000000
# 29             0.037500
# 30             0.344365
# 31             0.000000
